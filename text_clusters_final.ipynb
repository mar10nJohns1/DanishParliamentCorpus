# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import re
import seaborn as sns
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
nltk.download("punkt") # Download if not already downloaded (needed for sentence tockenizeing).
import pickle

# Load all necesary files and such.
#reading the data and resetting index.
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/DPC_speeches.csv', delimiter=",")
df = df.reset_index().iloc[:,2:]

#reading Oli's list of FT members
ft_mem = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fm3.csv')
#df = df[~((df['Navn'] == ', fg.'))] # Delete observation that doesnt make sense.
df = df[~df.Rolle.isin([', fg.'])] # Delete observation that doesnt make sense.
# read in stop words for danish as a list.
stopord_ = pd.read_csv("/content/drive/My Drive/Colab Notebooks/stopord.txt")    
stopord = []
for i in stopord_["ad"]:
    stopord.append(i)

df = df[['Starttid', 'Sluttid', 'Navn', 'Rolle', 'Tekst']]
df.head(1)

# Add parties to speakers
#checking how many unique names in our dataset
xml = list(df.Navn.unique())
len(xml)
#Checking how many names in the ft dataset
ft = list(ft_mem.Spørger.unique())
ft = [x[0:-1] for x in ft] #removing whitespace in the end of every name
len(ft)
set_ = list(set(xml) & set(ft)) # making a list of the set values
#removing whitespace in the end of every name
ft_mem['Spørger'] = ft_mem['Spørger'].apply(lambda x: x[0:-1])
#filtering out the names that we are looking for which are matching in the list of FT members
match = ft_mem[ft_mem['Spørger'].isin(set_)]
match.head()
#merging the two dataframes
df_m = df.merge(match, left_on = "Navn", right_on = "Spørger", how='left')
#looking only at specific columns
df_m = df_m[['Starttid', 'Sluttid', 'Navn', 'Rolle', 'Tekst', 'Parti']]
#only looking at relevant names
df_m = df_m[df_m.Navn!='None']
#checking which names does not have a party
df_m[df_m.isnull().Parti].Navn.unique()

df_m.iloc[0,-2]

# Starting text-processing
from gensim import utils
import gensim.parsing.preprocessing as gsp

filters = [
           gsp.strip_tags, 
           gsp.strip_punctuation,
           gsp.strip_multiple_whitespaces,
           gsp.strip_numeric
          ]
def clean_text(s):
    s = s.lower()
    s = utils.to_unicode(s)
    for f in filters:
        s = f(s)
    return s

# apply clean-text function to all the text
df_m['Tekst'] = df_m['Tekst'].apply(lambda x: clean_text(x))
# tokenizing all text
df_m['t_text'] = df_m['Tekst'].apply(lambda x: word_tokenize(x))
# Take out stop words
df_m['t_tekst_clean'] = df_m['t_text'].apply(lambda x: [word for word in x if not word in stopord])
# Removing the 'formand' of folketinget - it is usually not important the things he is saying
df_m = df_m[~df_m.Rolle.isin(['formand'])]
#choosing the stemmer
stemmer = SnowballStemmer("danish")
#testing 
stemmer.stem("spiser")
# Apply to all text.
df_m['stemmed'] = df_m['t_tekst_clean'].apply(lambda x: [stemmer.stem(item) for item in x])

# Classifying the text
# def dummy_fun(doc):
#     return doc
# tfidf = TfidfVectorizer(analyzer='word',tokenizer=dummy_fun, preprocessor=dummy_fun, token_pattern=None)
# docs = list(df_m.stemmed)
# tfidf.fit(docs)
# # fitting the tdfif vectorizer to our documents
# vector = tfidf.transform(docs)
# vector.shape
# true_k = 20
# model = KMeans(n_clusters=true_k, init='k-means++', max_iter=500, n_init=1)
# model.fit(vector)
# model_indices = model.fit_predict(vector)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
words = []
for i in range(len(df_m)):
   w = df_m["stemmed"].iloc[i] # Get words for the i'th text.
   words = words + w # Add the words from the i'th text to all previous words. 

with open("/content/drive/My Drive/Colab Notebooks/words.txt", "wb") as fp:   #Pickling
  pickle.dump(words, fp)

# %%
with open("/content/drive/My Drive/Colab Notebooks/words.txt", "rb") as fp:   # Unpickling
...   words = pickle.load(fp)

# %%
# Classifying the text
def dummy_fun(doc):
   return doc
tfidf = TfidfVectorizer(analyzer='word', tokenizer=dummy_fun, preprocessor=dummy_fun, token_pattern=None)
docs = list(df_m.stemmed)
tfidf.fit(docs)
# # fitting the tdfif vectorizer to our documents
vector = tfidf.transform(docs)
vector.shape
true_k = 25
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=500, n_init=1)
model.fit(vector)
model_indices = model.fit_predict(vector)

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = tfidf.get_feature_names()

# print the centroids into which clusters they belongs
for i in range(true_k):
    print("Cluster %d:" % i, end='')
    for ind in order_centroids[i, :50]:
         print(' %s' % terms[ind], end='')
    print()
# Out:
# Cluster 0: børn barn forældr famili ung rigt – år dansk mul hjælp kommun danmark minist men forslag altså dag ordfør regering ret forhold faktisk gern giv sikr vigt udsat tid problem tal arbejd tror mennesk tag fattigdom sted voksn brug sid samfund skol sig ting handl sag bedr ansvar går mor
# Cluster 1: hr – jens spørgsmål aaen frank svar lausts bjarn sig dansk regering altså gern spørg tror ole rigt dag mort tal enig forslag men ting år står forhold hækkerup sagt set faktisk christian sør giv sagd rasmus gang dahl danmark jesp hør karst forstå stil kristian debat venstr folketing socialdemokrati
# Cluster 2: arbejdsplads virksom danmark arbejd skab dansk job regering – skat vækst betal rigt sikr land virksomhed mennesk arbejdsmarked arbejdsløs år afgift beskæftig altså peng samfund mul brug giv folk dag tror nye gang gern forslag set faktisk økonomisk erhvervsliv økonomi kris led forhold bedr vigt måd politik hel lang selvfølg
# Cluster 3: lovforslag forslag støt mul – lov dansk dag del venstr sikr giv selvfølg regl tak ændring regering rigt forhold altså folketing gern spørgsmål set danmark ordfør vigt sid behandling står ting høringssvar stem forbind folkeparti ret grund områd behandl ønsk lovgivning ind handl ræk lig måd konservativ stil år borg
# Cluster 4: eu danmark land dansk – regl ret regering europa s samarbejd altså europæisk forhold forslag men arbejd spørgsmål kommission folketing mul rigt ting debat selvfølg sag dag gern sid tak sig områd hr forordning problem set ønsk tror ordfør faktisk aftal enig domstol ind minist direktiv sikr gang venstr tag
# Cluster 5: sf s ordfør forslag – regering hr dag svar sid politik spørg dansk gern hør støt sig altså spørgsmål står valg socialdemokrat set rigt tak men radikal tal forstå ting enig plan søvndal villy forhold år ønsk « faktisk » danmark stem arbejd venstr peng gang tror del går socialdemokrati
# Cluster 6: per claus hr enhedslist ørum jørgens dalgaard – spørgsmål spørg regering altså dansk sig tror rigt set danmark faktisk ting enig gern svar forslag stil forhold tal sagd dag aftal men sagt gang står selvfølg egent frem debat folketing mul hør forstå giv tid tag gå virk ret sid problem
# Cluster 7: venstr radikal ordfør – forslag regering gern svar politik hr dansk spørgsmål hør sig men rigt altså dag parti sid set danmark forstå står støt år spørg tak stem forhold ønsk tal aftal gang tror ting går valg enig faktisk giv peng sagt skat find virk konservativ arbejd egent tænk
# Cluster 8: statsminist regering spørgsmål – svar folketing dansk danmark spørg altså dag sig tal sagd ministr tak men enig gern forhold forstå land sag set rigt gang minist sid stil står eu egent debat tror hr arbejd venstr politik giv sas ting går sagt fald skat ret tid år hel virk
# Cluster 9: anders eigil hr damsbo lennart kim c h – hæstorp arbejd sophi svar sig sf altså arbejdsmarked spørg led spørgsmål dag rigt netop hør år regering forslag mennesk enig tror faktisk dansk egent gern ordfør men set venstr job socialdemokrati sagt giv virk folk tal mul måd fald gang tid
# Cluster 10: sag justitsminist politi straf – kriminalit altså dag regering person folketing domstol forslag forhold kriminel sid mul spørgsmål rigt forbryd fængsel dansk selvfølg problem tror tal sig set år dom giv begå men tid ting tag ret minist vold faktisk lov indsat alvor virk gang beslutningsforslag danmark folk blev sagt
# Cluster 11: trafik kollektiv bil – brug motorvej pris bedr tog peng hr betalingsring kør københavn regering enhedslist transport forslag venstr rigt kr altså faktisk vej bilist tror bus set mia minist dag gern ordfør mul sted pct sid hel lang pihl områd år dsb tal løft takst hovedstadsområd selvfølg sf ind
# Cluster 12: ordfør tak spørg gern – hør spørgsmål sig men konservativ forslag enig tal svar altså rigt socialdemokratisk dansk faktisk forhold venstr regering tænk enhedslist bekræft ting forstå dag egent står sagd danmark giv stil problem mennesk arbejd set sid år parti ret socialdemokrat peng går mul tror lovforslag gang radikal
# Cluster 13: – altså rigt spørgsmål tror forhold danmark mul men gern ting faktisk dag selvfølg giv forslag dansk set sig tal gang brug land arbejd måd spørg svar år problem enig områd går sted mennesk tag folk hel sagt sid ret tid forskel vigt tak gå find fald del lig står
# Cluster 14: minist spørgsmål svar – tak spørg regering sig gern men altså hør forhold enig tal problem rigt dag dansk giv lyd set områd danmark tænk gang sag faktisk forstå år stil forslag holdning ting står mul går sid arbejd brug egent fald virk kommun tid tror ind find tag folketing
# Cluster 15: dansk folkeparti folkepartis forslag – ordfør regering danmark gern hr konservativ altså rigt men dag sig stem år sid forhold støt faktisk spørgsmål ønsk parti ting giv tror set peng selvfølg samfund spørg gang mul står mennesk arbejd går folketing svar venstr hør sagt forstå del tak aftal problem tal
# Cluster 16: elev folkeskol skol lær klas undervisning fag kommun børn – rigt frie faktisk regering altså friskol brug mul minist giv forældr dansk bedr dag peng ordfør gern forhold test enkelt vigt elevplan uddan grundskol går tal år skoleled forslag undervisningsminist forskel tid tim løft måd del undervis sted sikr dygt
# Cluster 17: uddan ung ungdomsuddan mennesk stud videregå – rigt mul su år regering altså arbejd job brug gern faktisk arbejdsmarked sikr gang giv tag dansk forslag erhvervsuddan dag pct led vigt ordfør minist danmark problem peng tror del bedr men går forhold selvfølg gennemfør universitet hjælp tal ret ufaglært lovforslag gå
# Cluster 18: regering enhedslist – dansk forslag politik aftal altså finansminist set sid år valg spørgsmål danmark svar gern rigt står dag forhold parti peng sig folketing arbejd gang økonomisk venstr tror ting sagt faktisk tid giv spørg frem hr selvfølg tal tag men mul enig ønsk hel problem fald brug skat
# Cluster 19: kommun borg peng – kommunal regering giv opgav altså mul minist rigt faktisk områd brug gern ordfør forslag sid ude forhold sig set selvstyr aftal budget ting år enkelt økonomi ældr tror hjælp sted sikr dag udbud men måd region tal landsforening gang forskel økonomisk dansk selvfølg lovforslag spørgsmål kr
# Cluster 20: patient region behandling sygehus læg – sygdom sundhedsvæs minist behandl privat dag hurt regering dansk sikr offent ret peng sted mul privathospital ventetid altså rigt ansvar sundhedsvæsen brug men måned borg behandlingsgaranti ind sig praktis områd hospital giv vent gern forslag faktisk år tal spørgsmål lang tid udredning gang set
# Cluster 21: liberal allianc forslag hr ammitzbøl simon emil – ordfør gern regering dansk danmark støt politik men parti set ønsk altså dag faktisk skat offent spørgsmål stem forhold tror rigt giv tak tal går mennesk sid mul svar arbejd hør venstr spørg ting forstå år gang del sted står sig lovforslag
# Cluster 22: landbrug dansk erhverv landmænd regering – natur ordfør grøn rigt landmand økologisk ordning hr gern arbejdsplads forhold forslag venstr mul giv miljø danmark set faktisk produktion sikr tror landbrugskommission fremtid sig brug altså minist vækst peng står situation ting måd fødevar land økologi nye hel dyrevelfærd gang tal dag går
# Cluster 23: offent sektor privat ansat peng vækst – brug regering nulvækst pct år forbrug udgift altså dansk hr venstr velfærd kommun økonomi fær politik set dag danmark skat kr svar gern betyd bedr tror stør plan giv sig mia rigt frem mul økonomisk sted borg forhold sikr men faktisk arbejd spørgsmål
# Cluster 24: kr mia mio peng regering – brug år altså dansk skat skattelet giv hr betal find svar venstr tal rigt ordfør afgift gern forslag finansminist ekstra sig finansi spar offent minist kost danmark dag set spørgsmål kommun beløb pct året gang økonomi spørg økonomisk faktisk plan betyd tror men står

# %%
# Preview a centroid.
for ind in order_centroids[4]:
        print(' %s' % terms[ind], end='')
# Out:
#  eu danmark land dansk – regl ret regering europa s samarbejd altså europæisk forhold forslag men arbejd spørgsmål kommission folketing mul rigt ting debat selvfølg sag dag gern sid tak sig områd hr forordning problem set ønsk tror ordfør faktisk aftal enig domstol ind minist direktiv sikr gang venstr tag sagt lovgivning giv støt politik måd del diskut vedtag fæl enhedslist diskussion folkeparti vigt står går gæld handl hel lov økonomisk år spørg brug lang marked social sted tal gå lovforslag forskel bevæg grund politisk euro find betyd parti pct indr tid borg egent frem bestem børnecheck klart båd fald svar lig følg afgør ræk netop f holdning eks vid hvert folkeafstemning interes a finanspag overhold blev flertal ændr befolkning klar international konservativ hør virk medlemsland strid sagd stil beslutning statsminist lev national krav sæt vis forbehold bl fuldstænd virksom formandskab hensyn vej forbind læg tænk parlament græns før situation forstå verd løs haft løsning kom sidst bedr dom hold beslutningsforslag europaudvalg jam ansvar nødt deltag enkelt nye økonomi fri pres prøv optjeningsprincip sf opfat union radikal fællesskab fået medlem traktat socialdemokrat gansk præcis ord respek bland sær system betal valg god sker færø dumping tæt vel tvivl fornuft stærk send forbud skat implement lav initiativ udvikling plan fn høj kig rejs udfordring først kris folk mål skab grundlæg forhandling forp væk overensstem bidrag forsøg foregår ydels bruxel rent glad gennemfør arbejdskraft vælg nordisk nævnt lad håb forplig sammenhæng naturligvis socialdemokrati stem snus grad end samtid fuld osv fast euroland styrk stå overhoved stør fremtid ram velfærdsyd konsekvens rim tidspunk kræv tilfæld co mød indfør beslut fordel juridisk alvor drej start nødvend hinand spil kontrol nuvær fokus fortsat bedst indflyd vidt simpelt arbejdsmarked bekæmp udtryk kæmp ulov ske meld synspunk hvorvid hørt bestemt niveau tyskland tilhæng peng opmærksom princip vurdering baggrund regul stat idé udgangspunk anerkend sat sørg indgå ændring kør bankunion måned nævn udenlandsk uans lyd arbejdsplads positiv måt kend udvikl væsent undersøg mening argument rol retning påvirk omfat indsat hurt formand ophold kort konkret drøft konkr patent kamp tyd skyld storbritanni proc tilslut glæd forbrug uen øvr forstår punk styr finansiel beskyt helst øjeblik svært eksempel « » positivt tysk form behandl fint råd hånd var udenrigsminist patentdomstol bred stilling opgav frie gavn grundlag bemærkning natur vist stort mærk cabotagekørsel træf kr eksempelvis herund desvær england konstat arbejdstag betydning relevant bekend medlemsstat demokrati fremsat vedrør kern kina norg bekræft demokratisk såkald folkepartis vurd medlemskab bring saml træk slet vækst spilleregl yder interessant allianc forhandl suverænit snak formål adgang undr budgetlov spurg liberal opbakning forvent hed usa mandat rejst trod bak redegør tvær kompetenc åbn produk vilkår tiltag spor fortsæt egn sket offent resultat mennesk senest søg retsforbehold linj begynd nationalt model lissabontraktat folketingssal vegn fung løb israel tillad bank ordent behov skridt sikker person statsborg al understreg aktivt biograf sik ’ regi stemt ude forudsætning opfordr angår regulering konflik grænseoverskrid husk ordning forkert klima undgå reduktion samt gået magt målsætning fisk hvilk oplysning herhjem konkurrenc rund grøn fat byg praksis internationalt forestil fortolkning dialog samfund led direk kraft indført talt lagt kriminalit bekymr godkend problemstilling hjem sver europaråd nå optag mellemstats fin udvid part forhindr især små bryd bekymring læs vent skad skrev global bund foretag sanktion vend afgiv mas accept brugt revision konvention kald oplev rest dår hjælp børn frankr løn foreslå stram reduc afhæng udfordr hjemland blot su pia lej dyr sælg point vansk bord euroforbehold korrek flyt generelt åbenbart vandr socialdemokratisk udlænding øjn begræns selvstænd pålæg emn østeuropæisk justitsminist sigt plad dyrev ...

# %%
#df_m["stemmed"].shape == model_indices.shape
#df_m["Tekst"].shape == model_indices.shape
# Make sure both "Parti" shape and model_indices shape are equal.
df_m["Parti"].shape == model_indices.shape
#len(df_m["stemmed"])
#len(model_indices)
#model_indices
# Out:
# True

# %%
cluster_party = np.c_[model_indices, df_m["Parti"]] # Combine the two columns into one numpy array.

# %%
cluster_party.shape[0] == len(model_indices) # Make sure these are both the same length.
# Out:
# True

# %%
cluster_party = pd.DataFrame(data=cluster_party, columns=["cluster", "party"]) # Convert to pandas dataframe for easier data wrangling.

# %%
party_counts = cluster_party.groupby(["cluster", "party"]).size() # Show counts of parties in every cluster.
#with open("/content/drive/My Drive/Colab Notebooks/party_counts.txt", "wb") as fp:   #Pickling
 # pickle.dump(party_counts, fp)

# %%
pd.set_option("display.max_rows", 1000)
print(party_counts)
# Out:
# cluster  party
# 0        DF                278
#          EL                 72
#          KD                  1
#          KF                212
#          LA                 23
#          RV                 62
#          S                 104
#          SF                 37
#          SIU                 3
#          V                 173
#          udpeget af SF      10
# 1        ALT                32
#          DF                392
#          EL                171
#          KD                  7
#          KF                201
#          LA                157
#          RV                478
#          S                 101
#          SF                 50
#          UFG                 8
#          V                 587
# 2        ALT                90
#          DF                221
#          EL                408
#          IA                  2
#          JF                  2
#          KD                  6
#          KF                 44
#          LA                122
#          RV                353
#          S                1310
#          SF                401
#          SIU                 1
#          T                   2
#          UFG                15
#          V                 338
# 3        ALT                25
#          DF                351
#          EL                239
#          IA                  4
#          JF                  1
#          KD                  5
#          KF                251
#          LA                 77
#          RV                147
#          S                 665
#          SF                215
#          SIU                 2
#          UFG                 4
#          V                 319
# 4        ALT               111
#          DF               1271
#          EL               1059
#          IA                  3
#          JF                  7
#          KD                 19
#          KF                714
#          LA                344
#          RV                595
#          S                1783
#          SF                707
#          SIU                 1
#          SP                  6
#          T                  16
#          UFG                24
#          V                2316
#          udpeget af SF       5
# 5        ALT                 3
#          DF                924
#          EL                474
#          IA                  1
#          JF                  4
#          KF                864
#          LA                123
#          RV                157
#          S                1045
#          SF                242
#          SIU                 1
#          T                   4
#          UFG                10
#          V                 920
#          udpeget af SF       3
# 6        ALT               108
#          DF                947
#          EL                903
#          IA                 29
#          JF                  4
#          KD                 15
#          KF                318
#          LA                392
#          RV                361
#          S                 947
#          SF                547
#          UFG                26
#          V                1230
#          udpeget af SF       2
# 7        ALT                18
#          DF                236
#          EL                 85
#          KD                  3
#          KF                172
#          LA                 37
#          RV                 79
#          S                 685
#          SF                140
#          UFG                 4
#          V                 562
# 8        ALT               219
#          DF                643
#          EL                302
#          KD                  8
#          KF                489
#          LA                 73
#          RV                554
#          S                1109
#          SF                401
#          UFG                 1
#          V                1105
# 9        ALT                43
#          DF                728
#          EL                402
#          IA                  1
#          KD                  5
#          KF                559
#          LA                393
#          RV                415
#          S                1231
#          SF                542
#          SIU                 3
#          SP                  1
#          UFG                 3
#          V                1539
#          udpeget af SF       1
# 10       ALT                46
#          DF                751
#          EL                514
#          IA                  4
#          KD                  9
#          KF                715
#          LA                225
#          RV                544
#          S                1202
#          SF                500
#          SIU                 5
#          SP                  1
#          T                   1
#          UFG                 8
#          V                1363
#          udpeget af SF       7
# 11       ALT               461
#          DF               3799
#          EL               2693
#          IA                 65
#          JF                 43
#          KD                 80
#          KF               3276
#          LA               1085
#          RV               2342
#          S                5404
#          SF               2466
#          SIU                63
#          SP                 63
#          T                  39
#          UFG                56
#          V                6483
#          udpeget af SF      30
# 12       ALT                17
#          DF                301
#          EL                167
#          IA                  2
#          JF                  1
#          KD                  1
#          KF                103
#          LA                 94
#          RV                 88
#          S                 379
#          SF                 90
#          SIU                 2
#          SP                  6
#          T                   2
#          UFG                 1
#          V                 529
# 13       ALT                21
#          DF                245
#          EL                 87
#          KD                  5
#          KF                124
#          LA                 44
#          RV                 19
#          S                  19
#          SF                 16
#          UFG                 5
#          V                 693
# 14       ALT               125
#          DF               1239
#          EL                655
#          IA                  6
#          JF                  1
#          KD                  3
#          KF                346
#          LA                216
#          RV                312
#          S                1805
#          SF                559
#          SIU                 3
#          SP                  9
#          T                   4
#          UFG                23
#          V                1673
#          udpeget af SF       9
# 15       ALT                42
#          DF                145
#          EL                118
#          KD                  2
#          KF                 95
#          LA                 69
#          RV                157
#          S                 409
#          SF                164
#          V                 381
# 16       ALT                49
#          DF                285
#          EL                294
#          IA                  2
#          KD                  1
#          KF                154
#          LA                 74
#          RV                208
#          S                 730
#          SF                285
#          V                 534
#          udpeget af SF       3
# 17       ALT                20
#          DF                596
#          EL                360
#          IA                  3
#          JF                  2
#          KD                  2
#          KF                223
#          LA                129
#          RV                110
#          S                 266
#          SF                107
#          SP                  1
#          T                   1
#          UFG                 3
#          V                 682
# 18       ALT               120
#          DF               1266
#          EL                646
#          IA                  6
#          JF                  3
#          KD                 10
#          KF                208
#          LA                134
#          RV                349
#          S                1585
#          SF                466
#          SIU                 4
#          SP                  3
#          T                   1
#          UFG                20
#          V                 348
#          udpeget af SF       1
# 19       ALT                83
#          DF                513
#          EL                488
#          JF                  1
#          KD                  2
#          KF                409
#          LA                353
#          RV                246
#          S                 809
#          SF                260
#          T                   1
#          UFG                 6
#          V                 914
#          udpeget af SF       1
# 20       ALT                35
#          DF                653
#          EL                317
#          JF                  1
#          KD                  4
#          KF                191
#          LA                 96
#          RV                132
#          S                 771
#          SF                262
#          SP                  1
#          T                   2
#          UFG                13
#          V                1004
#          udpeget af SF       3
# 21       ALT                40
#          DF                154
#          EL                181
#          IA                  1
#          JF                  1
#          KD                  4
#          KF                 83
#          LA                609
#          RV                176
#          S                 411
#          SF                205
#          SIU                 1
#          UFG                 5
#          V                 157
# 22       ALT                37
#          DF                608
#          EL                496
#          IA                  5
#          JF                 26
#          KD                  6
#          KF                259
#          LA                109
#          RV                299
#          S                 740
#          SF                294
#          SIU                 1
#          SP                 16
#          T                   5
#          UFG                 9
#          V                 636
# 23       ALT                43
#          DF                540
#          EL                286
#          IA                  2
#          KD                  6
#          KF                258
#          LA                218
#          RV                258
#          S                 775
#          SF                272
#          SIU                 1
#          SP                  8
#          T                   3
#          UFG                 4
#          V                 982
# 24       ALT               338
#          DF               1991
#          EL               1641
#          IA                 49
#          JF                 24
#          KD                 68
#          KF               1385
#          LA                639
#          RV               1387
#          S                3800
#          SF               1629
#          SIU                29
#          SP                 10
#          T                  15
#          UFG                46
#          V                2464
#          udpeget af SF       4
# dtype: int64
