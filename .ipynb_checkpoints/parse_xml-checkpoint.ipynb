# %% [markdown]
# # Parsing of XML

# %%
import xml.etree.ElementTree as ET

# %%
pwd
# Out:
# '/Users/MartinJohnsen/Documents/Martin Johnsen/MMC/4. Semester/Computational Data Analysis/Projects/Case2/DanishParliamentCorpus'

# %% [markdown]
# ### exploring xml (https://www.datacamp.com/community/tutorials/python-xml-elementtree)

# %%
#loading the XML tree
#tree = ET.parse('../data/EdixiXMLExport_20161.xml')
tree = ET.parse('../data/EdixiXMLExport_20091.xml')

# %%
#defining the root
root = tree.getroot()

# %%
#checking root
root.tag
# Out:
# 'EdixiData'

# %%
#defining all emelemts that are following down through the tree, from the root. 
all_elements = [elem.tag for elem in root.iter()]

# %%
#the elements are in a list from here
#all_elements

# %% [markdown]
# It is obvious that the list of elements follows a structure. All of the values will have to be imputed into a pandas at some point, hence as MVP just impute what might seems to be the easiest.

# %%
#looking at the first 6 elements in the tree (they will quickly become the same, as some of the elements are the same)
#uncomment print-statements to see 
for element in all_elements:
    #print("\n",element)
    for i, obj in enumerate(root.iter(element)):
        #print(obj.text)
        if i==5:
            break

# %%
#checking the different names (uncomment to see)
#for meeting in root.iter('Navn'):
#    print(meeting.text)

# %% [markdown]
# #### It is obvious how to get the different things out --> this is made into a pandas, where every row holds the different arrtibutes for a given speech
#
# The idea is, that I am taking out all the important things for each speech by the following attributes:
# - 'Tale'
# - 'Starttid'
# - 'Sluttid'
# - 'Navn'
# - 'Rolle'
# - 'Tekst'
#
# The above mentioned are all attributes that are specific for every single speech, and will therefore be the easiest to process.

# %%
import pandas as pd

# %%
def iter_element(root, name_of_element):
    emp_list = []
    for el in root.iter(name_of_element):
        var = str(el.text)
        if var == "":
            var = 'empty'
        emp_list.append(var)
    return emp_list

# %%
def xml_to_pandas(xml_root):
    columns = ['Tale','Starttid','Sluttid','Navn','Rolle','Tekst']
    
    df = pd.DataFrame(columns = columns)
    
    lists_ = []
    for element in columns:
        element_list = iter_element(xml_root, element)
        lists_.append(element_list)
    
    
    #adding to df
    for i in range(len(columns)):
        df[columns[i]] = pd.Series(lists_[i])
    
    return lists_ , df

# %%
lists_ , df = xml_to_pandas(root)

# %%
for i in range(len(lists_)):
    print(len(lists_[i]))
# Out:
# 61562
# 61562
# 61562
# 61562
# 61562
# 61562

# %%
len(df)
# Out:
# 61562

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 61562

# %%
df.tail(50)
# Out:
#        Tale                 Starttid                  Sluttid  \
# 61512  None  2009-11-27T12:18:56.667  2009-11-27T12:18:59.430
# 61513  None  2009-11-27T12:18:59.430  2009-11-27T12:19:34.133
# 61514  None  2009-11-27T12:19:34.133  2009-11-27T12:19:38.273
# 61515  None  2009-11-27T12:19:38.273  2009-11-27T12:19:57.510
# 61516  None  2009-11-27T12:19:57.510  2009-11-27T12:20:00.837
# 61517  None  2009-11-27T12:20:00.837  2009-11-27T12:20:48.430
# 61518  None  2009-11-27T12:20:48.430  2009-11-27T12:21:11.650
# 61519  None  2009-11-27T12:21:11.650  2009-11-27T12:24:56.927
# 61520  None  2009-11-27T12:24:56.927  2009-11-27T12:25:03.627
# 61521  None  2009-11-27T12:25:03.627  2009-11-27T12:25:48.317
# 61522  None  2009-11-27T12:25:48.317  2009-11-27T12:25:50.410
# 61523   René Christensen   medlem
# 61524  Helge Adam Møller  formand
# 61525  Benny Engelbrecht   medlem
# 61526  Helge Adam Møller  formand
# 61527   René Christensen   medlem
# 61528  Helge Adam Møller  formand
# 61529        Per Clausen   medlem
# 61530  Helge Adam Møller  formand
# 61531   René Christensen   medlem
# 61532  Helge Adam Møller  formand
# 61533        Per Clausen   medlem
# 61534  Helge Adam Møller  formand
# 61535   René Christensen   medlem
# 61536  Helge Adam Møller  formand
# 61537     Pia Olsen Dyhr   medlem
# 61538  Helge Adam Møller  formand
# 61539   René Christensen   medlem
# 61540  Helge Adam Møller  formand
# 61541     Pia Olsen Dyhr   medlem
# 61542  Helge Adam Møller  formand
# 61543   René Christensen   medlem
# 61544  Helge Adam Møller  formand
# 61545     Pia Olsen Dyhr   medlem
# 61546  Helge Adam Møller  formand
# 61547       Henrik Høegh   medlem
# 61548  Helge Adam Møller  formand
# 61549     Pia Olsen Dyhr   medlem
# 61550  Helge Adam Møller  formand
# 61551       Henrik Høegh   medlem
# 61552  Helge Adam Møller  formand
# 61553     Pia Olsen Dyhr   medlem
# 61554  Helge Adam Møller  formand
# 61555          Vivi Kier   medlem
# 61556  Helge Adam Møller  formand
# 61557         Bente Dahl   medlem
# 61558  Helge Adam Møller  formand
# 61559        Per Clausen   medlem
# 61560        Per Clausen   medlem
# 61561  Helge Adam Møller  formand
#
#                                                    Tekst
# 61512                              Så er det ordføreren.
# 61513  Jeg henviste faktisk i min ordførertale til de...
# 61514  Så er der yderligere en kort bemærkning fra hr...
# 61515  Ja, i en række andre produkter, hvor det så er...
# 61516                              Så er det ordføreren.
# 61517  Jeg synes, at det er udmærket, at vi har EFSA ...
# 61518  Der er ikke flere korte bemærkninger, tak til ...
# 61519  Som udgangspunkt er det her jo faktisk et rigt...
# 61520  Der er foreløbig tre korte bemærkninger til or...
# 61521  Tak. Det her er et beslutningsforslag, og derf...
# 61522                              Så er det ordføreren.
# 61523  Det kan jeg kun bekræfte. Som jeg også sagde h...
# 61524  Der er yderligere en kort bemærkning fra hr. B...
# 61525  Tak. I fortsættelse af den diskussion vil jeg ...
# 61526                              Så er det ordføreren.
# 61527  Hvis man holder sig til det konkrete om bisfen...
# 61528  Så er der en kort bemærkning fra hr. Per Clausen.
# 61529  Jeg synes jo, at Dansk Folkeparti måske skulle...
# 61530                              Så er det ordføreren.
# 61531  Der var sådan flere spørgsmål i det samme. Man...
# 61532  Så er det hr. Clausen for en sidste kort bemær...
# 61533  Nu har vi jo gode erfaringer på det her område...
# 61534                              Så er det ordføreren.
# 61535      Jeg kan bekræfte, at jeg er meget enig i det.
# 61536  Så er der en kort bemærkning fra fru Pia Olsen...
# 61537  Jeg synes, det er positivt, at Dansk Folkepart...
# 61538                              Så er det ordføreren.
# 61539  Det, jeg kunne forestille mig man kunne gøre i...
# 61540  Og så er der en sidste kort bemærkning fra fru...
# 61541  Nu er det jo ikke nogen hemmelighed, at Dansk ...
# 61542                              Så er det ordføreren.
# 61543  Man skal selvfølgelig ikke lægge sig fast på é...
# 61544  Tak til ordføreren. Vi går videre i ordførerræ...
# 61545  Man har i årevis haft mistanke om, at kemikali...
# 61546    Der er en kort bemærkning fra hr. Henrik Høegh.
# 61547  Heller ikke her hørte jeg meget om den frivill...
#                                                    Tekst
# 47370                                        Ordføreren.
# 47371  Jo, de to ting hænger sådan set overhovedet ik...
# 47372                                         Spørgeren.
# 47373  Tak. Det er også fint, at Enhedslisten kommer ...
# 47374                                        Ordføreren.
# 47375  Det er alene et spørgsmål om prioritering. Som...
# 47376  Tak til Enhedslistens ordfører. Den næste tale...
# 47377  Som jeg ser forslaget her, så kan der ved at l...
# 47378  Tak til ordføreren. Næste i rækken er hr. René...
# 47379  Tak for det. I Alternativet har vi hele tiden ...
# 47380  Tak til ordføreren. Der er ingen korte bemærkn...
# 47381  Det forrige punkt om kystsikring tog væsentlig...
# 47382  Der er en enkelt kort bemærkning fra hr. Rasmu...
# 47383  Jamen bare for god ordens skyld vil jeg sige, ...
# 47384                                        Ordføreren.
# 47385  Vi stemmer for det her beslutningsforslag, som...
# 47386  Der er ikke flere korte bemærkninger, så vi gå...
# 47387  Da jeg skulle tage stilling til det her forsla...
# 47388  Tak til hr. Holger K. Nielsen. Vi går videre i...
# 47389  Hos Konservative har vi besluttet os, og vi st...
# 47390  Der er et par korte bemærkninger. Først er det...
# 47391  Tak. Jeg troede, jeg havde en aftale med hr. R...
# 47392                                        Ordføreren.
# 47393  Jeg synes nu nok, jeg svarede på det. Det, jeg...
# 47394                                 Søren Søndergaard.
# 47395  Undskyld, men tror hr. Rasmus Jarlov virkelig,...
# 47396                                        Ordføreren.
# 47397  Jeg vil gerne anerkende hr. Søren Søndergaards...
# 47398                           Så er det hr. René Gade.
# 47399  Jeg reagerede egentlig bare på ordførerens kom...
# 47400                                        Ordføreren.
# 47401  Jeg mener ikke, at jeg sagde, at alle fornufti...
# 47402                                     Hr. René Gade.
# 47403  Jamen det kan være, at jeg har overfortolket d...
# 47404                              Så er det ordføreren.
# 47405  Jeg mener, at der er overvældende grund til at...
# 47406  Tak til hr. Rasmus Jarlov. Så er det udenrigsm...
# 47407  Tak for det, og tak for ordet.Vi befinder os i...
# 47408  Der er en kort bemærkning, først fra hr. Søren...
# 47409  Jeg går ud fra, at ministeren er enig med mig ...
# 47410                                Udenrigsministeren.
# 47411  Jeg vil ikke stå her og tage stilling til et s...
# 47412  Hr. Søren Søndergaard?Nej. Så er det hr. René ...
# 47413  Jeg vil bare godt høre, om ministeren kunne ko...
# 47414                                Udenrigsministeren.
# 47415  Jeg kan ikke sætte procentsatser på, hvad man ...
# 47416                                     Hr. René Gade.
# 47417  Tak for svaret, men jeg mente egentlig mere i ...
# 47418                    Det synes jeg lyder fornuftigt.
# 47419  Tak til udenrigsministeren. Da der ikke er fle...

# %% [markdown]
# #### Checks:

# %%
#in line 38 Thomas Danielsen is talking, so check if his name is mentioned in the line before
df.iloc[37,5]
# Out:
# 'Tak til ordføreren. Den næste ordfører er hr. Thomas Danielsen, Venstre.'

# %%
#in line 40 Henning Hyllested is talking, so check if his name is mentioned in the line before
df.iloc[39,5]
# Out:
# 'Tak til Venstres ordfører. Den næste ordfører er hr. Henning Hyllested, Enhedslisten.'

# %%
df.iloc[43,5]
# Out:
# 'Tak til ordføreren. Den næste ordfører er hr. René Gade, Alternativet.'

# %% [markdown]
# All good until line 50.

# %%
df.iloc[5688,5]
# Out:
# 'Tak for det. Og den første korte bemærkning kommer fra hr. Jan E. Jørgensen, Venstre.'
